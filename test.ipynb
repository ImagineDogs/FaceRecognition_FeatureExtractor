# %%
import pandas as pd
import cv2

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
results = model.predict(source='0', show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 88.2ms
# 0: 480x640 (no detections), 84.2ms
# 0: 480x640 (no detections), 79.8ms
# 0: 480x640 (no detections), 78.5ms
# 0: 480x640 (no detections), 80.7ms
# 0: 480x640 (no detections), 77.5ms
# 0: 480x640 (no detections), 121.7ms
# 0: 480x640 (no detections), 79.9ms
# 0: 480x640 (no detections), 73.2ms
# 0: 480x640 (no detections), 78.5ms
# ...

# %%
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
df = pd.read_csv('archive/faces.csv')
df
# Out:
#         image_name  width  height   x0   y0    x1   y1
# 0     00001722.jpg   1333    2000  490  320   687  664
# 1     00001044.jpg   2000    1333  791  119  1200  436
# 2     00001050.jpg    667    1000  304  155   407  331
# 3     00001736.jpg    626     417  147   14   519  303
# 4     00003121.jpg    626     418  462   60   599  166
# ...            ...    ...     ...  ...  ...   ...  ...
# 3345  00002232.jpg    620     349    4   36   186  158
# 3346  00002232.jpg    620     349  122  103   344  248
# 3347  00002232.jpg    620     349  258  118   541  303
# 3348  00002232.jpg    620     349  215   11   362  108
# 3349  00002232.jpg    620     349  330    1   487   81
#
# [3350 rows x 7 columns]

# %%
path = '00001722.jpg'

# %%
a = df.loc[df['image_name'] == path].iloc[0]
a
# Out:
# image_name    00001722.jpg
# width                 1333
# height                2000
# x0                     490
# y0                     320
# x1                     687
# y1                     664
# Name: 0, dtype: object

# %%
import cv2
im = cv2.imread(f'datasets/data/images/train/{path}')
im.shape
# Out:
# (2000, 1333, 3)

# %%
a['x0']
# Out:
# 490

# %%
im2 = im[a['y0']:a['y1'], a['x0']:a['x1']]
im2
# Out:
# array([[[210, 228, 251],
#         [210, 228, 251],
#         [210, 228, 251],
#         ...,
#         [209, 226, 252],
#         [209, 226, 252],
#         [209, 226, 252]],
#
#        [[210, 228, 251],
#         [210, 228, 251],
#         [210, 228, 251],
#         ...,
#         [209, 226, 252],
#         [209, 226, 252],
#         [209, 226, 252]],
#
#        [[210, 228, 251],
#         [210, 228, 251],
#         [210, 228, 251],
#         ...,
#         [209, 226, 252],
#         [209, 226, 252],
#         [209, 226, 252]],
#
#        ...,
#
#        [[208, 225, 251],
#         [208, 225, 251],
#         [208, 225, 251],
#         ...,
#         [160, 143, 147],
#         [198, 181, 185],
#         [204, 189, 193]],
#
#        [[208, 225, 251],
#         [208, 225, 251],
#         [208, 225, 251],
#         ...,
#         [191, 174, 178],
#         [192, 175, 179],
#         [211, 196, 200]],
#
#        [[208, 225, 251],
#         [208, 225, 251],
#         [208, 225, 251],
# ...

# %%
window_name = 'image'
# im = cv2.imread('Vu2Nqwb.jpg')
cv2.imshow(window_name, im2)
cv2.waitKey(0) 
cv2.destroyAllWindows()
