# %%
from ultralytics import YOLO

# %%
model = YOLO('best.pt')

# %%
# Load a model
# model = YOLO('yolov8s-pose.yaml')  # build a new model from YAML
model = YOLO('yolov8s.pt')  # load a pretrained model (recommended for training)

# Train the model
model.train(data='archive/face.yaml', epochs=30)
valid_results = model.val()
print(valid_results)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 25.4MB/s]
# New https://pypi.org/project/ultralytics/8.0.205 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.203  Python-3.11.5 torch-2.1.0+cpu CPU (12th Gen Intel Core(TM) i3-12100F)
# ...

# %%
results = model.predict(source='0', show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 323.3ms
# 0: 480x640 (no detections), 167.8ms
# 0: 480x640 (no detections), 158.9ms
# 0: 480x640 (no detections), 153.9ms
# 0: 480x640 (no detections), 168.6ms
# 0: 480x640 (no detections), 159.1ms
# 0: 480x640 (no detections), 159.0ms
# 0: 480x640 (no detections), 160.1ms
# 0: 480x640 (no detections), 157.4ms
# ...

# %%
import cv2
# window_name = 'image'
# im = cv2.imread('Vu2Nqwb.jpg')
# cv2.imshow(window_name, im)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
print(results)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'FACE'}
# orig_img: array([[[105, 110, 119],
#         [101, 107, 114],
#         [109, 113, 118],
#         ...,
#         [ 52,  51,  47],
#         [ 49,  48,  44],
#         [ 50,  49,  45]],
#
#        [[106, 111, 120],
#         [105, 111, 118],
#         [111, 115, 120],
#         ...,
#         [ 50,  49,  45],
#         [ 48,  47,  43],
#         [ 50,  49,  45]],
#
#        [[106, 111, 120],
#         [108, 114, 121],
#         [113, 117, 122],
#         ...,
#         [ 53,  50,  46],
#         [ 51,  50,  46],
#         [ 52,  51,  47]],
#
#        ...,
#
#        [[164,  64, 129],
#         [168,  68, 133],
#         [163,  63, 129],
#         ...,
#         [163, 145, 146],
#         [163, 145, 146],
#         [165, 147, 148]],
#
#        [[161,  61, 126],
#         [164,  64, 129],
#         [161,  61, 127],
# ...

# %%
results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'FACE'}
# orig_img: array([[[105, 110, 119],
#         [101, 107, 114],
#         [109, 113, 118],
#         ...,
#         [ 52,  51,  47],
#         [ 49,  48,  44],
#         [ 50,  49,  45]],
#
#        [[106, 111, 120],
#         [105, 111, 118],
#         [111, 115, 120],
#         ...,
#         [ 50,  49,  45],
#         [ 48,  47,  43],
#         [ 50,  49,  45]],
#
#        [[106, 111, 120],
#         [108, 114, 121],
#         [113, 117, 122],
#         ...,
#         [ 53,  50,  46],
#         [ 51,  50,  46],
#         [ 52,  51,  47]],
#
#        ...,
#
#        [[164,  64, 129],
#         [168,  68, 133],
#         [163,  63, 129],
#         ...,
#         [163, 145, 146],
#         [163, 145, 146],
#         [165, 147, 148]],
#
#        [[161,  61, 126],
#         [164,  64, 129],
#         [161,  61, 127],
# ...

# %%
vid = cv2.imread('video.mp4')

# %%
type(vid)
# Out:
# NoneType

# %%
import cv2
window_name = 'image'
im = cv2.imread('Vu2Nqwb.jpg')
cv2.imshow(window_name, im)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
for box in results[0].boxes:
    top_left_x = int(box.xyxy.tolist()[0][0])
    top_left_y = int(box.xyxy.tolist()[0][1])
    bottom_right_x = int(box.xyxy.tolist()[0][2])
    bottom_right_y = int(box.xyxy.tolist()[0][3])
    cv2.rectangle(im, (top_left_x, top_left_y), (bottom_right_x, bottom_right_y), (50, 200, 129), 2)

# %%
top_left_x, bottom_right_x, top_left_y, bottom_right_y
# Out:
# (650, 1032, 126, 605)

# %%
im = cv2.imread('Vu2Nqwb.jpg')
# im[top_left_y: bottom_right_y, top_left_x:bottom_right_x]
cv2.imshow(window_name, im[top_left_y: bottom_right_y, top_left_x:bottom_right_x])
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
import cv2

# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# Read the input image
img = cv2.imread('lacto.jpg')
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces

# %%
faces = face_cascade.detectMultiScale(gray)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
# Display the output
cv2.imshow('img', img)
cv2.waitKey()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\pedro\OneDrive\Documentos\GitHub\FaceRecognition_FeatureExtractor\main.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pedro/OneDrive/Documentos/GitHub/FaceRecognition_FeatureExtractor/main.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> faces = face_cascade.detectMultiScale(gray)
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/OneDrive/Documentos/GitHub/FaceRecognition_FeatureExtractor/main.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> # Draw rectangle around the faces
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/OneDrive/Documentos/GitHub/FaceRecognition_FeatureExtractor/main.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> for (x, y, w, h) in faces:
#
# ...

# %%
import cv2 as cv
img = cv2.imread('lacto.jpg')
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def detectAndDisplay(frame):
    frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    frame_gray = cv.equalizeHist(frame_gray)
    #-- Detect faces
    faces = face_cascade.detectMultiScale(frame)
    face_list = []
    for (x,y,w,h) in faces:
        center = (x + w//2, y + h//2)
        frame = cv.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
        # frame = cv.ellipse(frame, center, (w//2, h//2), 0, 0, 360, (255, 0, 255), 4)
        face_list.append(frame_gray[y:y+h,x:x+w])
        #-- In each face, detect eyes
        # eyes = eyes_cascade.detectMultiScale(faceROI)
        # for (x2,y2,w2,h2) in eyes:
        #     eye_center = (x + x2 + w2//2, y + y2 + h2//2)
        #     radius = int(round((w2 + h2)*0.25))
        #     frame = cv.circle(frame, eye_center, radius, (255, 0, 0 ), 4)
    return frame, face_list

im, faces = detectAndDisplay(img)

# %%
cv.imshow('Capture - Face detection', face)

# %%
from IPython.display import display

# %%
display(face)
# Out:
# array([[[ 61,  69,  69],
#         [ 62,  70,  70],
#         [ 63,  71,  71],
#         ...,
#         [ 28,  28,  28],
#         [ 28,  28,  28],
#         [ 28,  28,  28]],
#
#        [[ 61,  69,  69],
#         [ 62,  70,  70],
#         [ 63,  71,  71],
#         ...,
#         [ 28,  28,  28],
#         [ 28,  28,  28],
#         [ 28,  28,  28]],
#
#        [[ 61,  69,  69],
#         [ 61,  69,  69],
#         [ 63,  71,  71],
#         ...,
#         [ 28,  28,  28],
#         [ 28,  28,  28],
#         [ 28,  28,  28]],
#
#        ...,
#
#        [[ 60,  76,  75],
#         [ 58,  74,  73],
#         [ 64,  80,  79],
#         ...,
#         [102, 105, 119],
#         [112, 115, 129],
#         [120, 123, 137]],
#
#        [[ 55,  70,  72],
#         [ 53,  68,  70],
#         [ 61,  76,  78],
#         ...,
#         [113, 116, 130],
#         [131, 134, 148],
#         [143, 146, 160]],
#
#        [[ 53,  68,  70],
#         [ 50,  65,  67],
#         [ 54,  69,  71],
# ...

# %%
from matplotlib import pyplot as plt
plt.imshow(im, interpolation='nearest')
plt.show()

# %%
plt.imshow(faces[0])
plt.show()

# %%
faces[0]
# Out:
# array([275, 456,  66,  66])
